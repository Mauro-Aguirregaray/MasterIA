# %%
from scipy import stats
import numpy as np
import pandas as pd

# %%
islander_data = pd.read_csv('https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/CEIA_Analisis_de_datos/main/clase_2/datasets/Islander_data.csv')

# %%
islander_data.head(5)
# Out:
#   first_name last_name  age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# 0    Bastian  Carrasco   25               H       1    A              63.5
# 1       Evan  Carrasco   52               S       1    A              41.6
# 2  Florencia  Carrasco   29               H       1    A              59.7
# 3      Holly  Carrasco   50               S       1    A              51.7
# 4     Justin  Carrasco   52               H       1    A              47.0
#
#    Mem_Score_After  Diff
# 0             61.2  -2.3
# 1             40.7  -0.9
# 2             55.1  -4.6
# 3             51.2  -0.5
# 4             47.1   0.1

# %%
islander_data.mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 islander_data.mean()
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/frame.py:11680, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11672 @doc(make_doc("mean", ndim=2))
#   11673 def mean(
#   11674     self,
#    (...)
#   11678     **kwargs,
#   11679 ):
# > 11680     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11681     if isinstance(result, Series):
#   11682         result = result.__finalize__(self, method="mean")
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12370 nv.validate_func(name, (), kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/frame.py:11549, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11545     df = df.T
#   11547 # After possibly _get_data and transposing, we are now in the
#   11548 #  simple case where we can use BlockManager.reduce
# > 11549 res = df._mgr.reduce(blk_func)
#   11550 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11551 if out_dtype is not None and out.dtype != "boolean":
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/internals/managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/internals/blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/frame.py:11468, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11466         return np.array([result])
#   11467 else:
# > 11468     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File /opt/conda/miniconda3/envs/ceia-add/lib/python3.12/site-packages/pandas/core/nanops.py:1686, in _ensure_numeric(x)
#    1683 inferred = lib.infer_dtype(x)
#    1684 if inferred in ["string", "mixed"]:
#    1685     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1686     raise TypeError(f"Could not convert {x} to numeric")
#    1687 try:
#    1688     x = x.astype(np.complex128)
#
# TypeError: Could not convert ['...'
#  '...'
#  'HSHSHSSHHSSSHHSHSHSHSHSHSHSSHHSHSHSHSHSSHHSSHHSHHSSHHSSHSSHHSHSHSHSHHSHHSHSSSHSHSHHSSHSHSHHSSHHSSSHHSSHHSHSHSSHSHHSHHSSHSSHHSHSHSHSHSSHHSHSHSHHSSSHHSHSSHHSHSHHSSHSHSSHSHSSHHHSHSHHSHSSHSHHSHSHSHHSSHS'
#  'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAASSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT'] to numeric

# %%
islander_data.std()
# Out:
# C:\Users\pablo.nahuel.pelli\AppData\Local\Temp\ipykernel_24636\324209366.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   islander_data.std()
# age                 12.023099
# Dosage               0.818504
# Mem_Score_Before    15.766007
# Mem_Score_After     18.133851
# Diff                10.754603
# dtype: float64

# %%
cov_mat = islander_data[['Mem_Score_Before', 'Mem_Score_After']].cov()

cov_mat
# Out:
#                   Mem_Score_Before  Mem_Score_After
# Mem_Score_Before        248.566970       230.871027
# Mem_Score_After         230.871027       328.836560

# %%
islander_data[['Mem_Score_Before', 'Mem_Score_After']].corr()
# Out:
#                   Mem_Score_Before  Mem_Score_After
# Mem_Score_Before          1.000000         0.807528
# Mem_Score_After           0.807528         1.000000

# %%
islander_data.median()
# Out:
# C:\Users\pablo.nahuel.pelli\AppData\Local\Temp\ipykernel_24636\3894949687.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   islander_data.median()
# age                 37.00
# Dosage               2.00
# Mem_Score_Before    54.80
# Mem_Score_After     56.75
# Diff                 1.70
# dtype: float64

# %%
islander_data.describe()
# Out:
#               age      Dosage  Mem_Score_Before  Mem_Score_After        Diff
# count  198.000000  198.000000        198.000000       198.000000  198.000000
# mean    39.530303    1.989899         57.967677        60.922222    2.954545
# std     12.023099    0.818504         15.766007        18.133851   10.754603
# min     24.000000    1.000000         27.200000        27.100000  -40.400000
# 25%     30.000000    1.000000         46.525000        47.175000   -3.175000
# 50%     37.000000    2.000000         54.800000        56.750000    1.700000
# 75%     48.000000    3.000000         68.400000        73.250000    5.925000
# max     83.000000    3.000000        110.000000       120.000000   49.000000

# %%
islander_data.mode()
# Out:
#   first_name last_name   age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# 0        Jun    Durand  37.0               H     1.0    A              90.0
# 1        NaN       NaN   NaN               S     NaN  NaN               NaN
#
#    Mem_Score_After  Diff
# 0             90.0  -1.3
# 1             96.0   0.0

# %%
islander_data.skew()
# Out:
# C:\Users\pablo.nahuel.pelli\AppData\Local\Temp\ipykernel_24636\4146418078.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   islander_data.skew()
# age                 1.069270
# Dosage              0.018699
# Mem_Score_Before    0.646570
# Mem_Score_After     0.756992
# Diff                0.766206
# dtype: float64

# %%
islander_data.kurt(numeric_only=True)
# Out:
# age                 0.888832
# Dosage             -1.507182
# Mem_Score_Before   -0.026350
# Mem_Score_After     0.180319
# Diff                3.379966
# dtype: float64

# %%
import seaborn as sns

# %%
sns.pairplot(islander_data)

# %%
sns.boxplot(data = islander_data, y = 'Diff')
# Out:
# <AxesSubplot:ylabel='Diff'>

# %%
sns.boxplot(islander_data.Mem_Score_Before)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(islander_data.Mem_Score_After)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=islander_data['Drug'], y=islander_data['Diff'])
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Diff'>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.random.normal(5,5,250)
Y = np.random.rayleigh(5,250)

percs = np.linspace(0,100,21)
qn_a = np.percentile(X, percs)
qn_b = np.percentile(Y, percs)

plt.plot(qn_a,qn_b, ls="", marker="o")

x = np.linspace(np.min((qn_a.min(),qn_b.min())), np.max((qn_a.max(),qn_b.max())))
plt.plot(x,x, color="k", ls="--")

plt.show()

# %%
X = np.random.normal(0,1,len(islander_data))
Y = (islander_data.Mem_Score_After - islander_data.Mem_Score_After.mean()) / islander_data.Mem_Score_After.std()

percs = np.linspace(0,100,21)
qn_a = np.percentile(X, percs)
qn_b = np.percentile(Y, percs)

plt.plot(qn_a,qn_b, ls="", marker="o")

x = np.linspace(np.min((qn_a.min(),qn_b.min())), np.max((qn_a.max(),qn_b.max())))
plt.plot(x,x, color="k", ls="--")

plt.show()
